# %%
import tensorflow as tf

# %%
tf.Variable(name='variable')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-92a50f4f12ea> in <module>()
# ----> 1 tf.Variable(name='variable')
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint)
#     211           dtype=dtype,
#     212           expected_shape=expected_shape,
# --> 213           constraint=constraint)
#     214
#     215   def __repr__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in _init_from_args(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, expected_shape, constraint)
#     271     _ = expected_shape
#     272     if initial_value is None:
# ...

# %%
tf.Variable
# Out:
# tensorflow.python.ops.variables.Variable

# %%
import os as os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Allen\\AnacondaProjects'

# %%
ls=pd.DataFrame(pd.read_excel('record.xls'))

# %%
ls.shape
# Out:
# (265, 25)

# %%
ls.isnull
# Out:
# <bound method NDFrame.isnull of      activity                            activityId  calorie commitId  \
# 0           1  75238287-15ff-44cb-a200-d6f729b802ca     1516     null
# 1           1  22d0e099-3862-443d-9096-3edfe72d5f3d        0     null
# 2           2  3a07edcb-794c-472c-852b-3730ba471b09        0     null
# 3           2  f9173980-8e9a-4f92-b901-c9fcdb94e691        0     null
# 4           1  7cb4a655-c2cd-4f98-89ce-74893ee12c8e     1516     null
# 5           1  a58b4c76-5c10-42bb-814e-1ccc6fca601a     1516     null
# 6           1  4c16b3b7-3cc9-4d53-8f82-df2df852b5c2        0     null
# 7           1  0d8e49ba-2d0f-4f4b-97bd-f91924ec693c        0     null
# 8           4  9a833551-0fb1-4366-b1d5-0ecb014c6439     1516     null
# 9           2  b7e2566a-15dc-48c1-8603-f312d23d2e09        4     null
# 10          2  a1380ad6-d929-4583-bd39-3c70f0f11dd8        0     null
# 11          1  1d976b72-db34-4528-b8a5-e24b9a68d396     1516     null
# ...

# %%
ls.columns('activity')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-fdb06b6b89f3> in <module>()
# ----> 1 ls.columns('activity')
#
# TypeError: 'Index' object is not callable

# %%
ls['activity'].count
# Out:
# <bound method Series.count of 0      1
# 1      1
# 2      2
# 3      2
# 4      1
# 5      1
# 6      1
# 7      1
# 8      4
# 9      2
# 10     2
# 11     1
# 12     1
# 13     1
# 14     1
# 15     1
# 16     1
# 17     1
# 18     1
# 19     1
# 20     1
# 21     4
# 22     4
# 23     4
# 24     4
# 25     4
# 26     4
# 27     4
# 28     4
# 29     4
#       ..
# 235    2
# 236    2
# 237    2
# 238    2
# 239    2
# 240    1
# 241    1
# 242    1
# 243    1
# 244    1
# 245    2
# 246    2
# 247    1
# 248    1
# 249    4
# 250    1
# 251    1
# 252    1
# 253    1
# 254    2
# 255    1
# 256    4
# 257    1
# 258    1
# 259    2
# 260    4
# 261    4
# 262    1
# 263    4
# 264    1
# Name: activity, Length: 265, dtype: int64>

# %%
len(ls['activity'].unique())
# Out:
# 5

# %%
ls['duration'].sum()/(1000*60*60)
# Out:
# 80.19468805555556

# %%
(ls['version']!=2).sum()
# Out:
# 16

# %%
plt.boxplot(ls['duration'])
plt.show()

# %%
bins =[0,100,200,300,400,500000]
plt.hist(ls['duration'],bins,normed=1,histtype='bar',rwidth=1)
plt.show()

# %%
c =ls[['duration','activity']]
c.corr()
# Out:
#           duration  activity
# duration  1.000000 -0.092736
# activity -0.092736  1.000000

# %%
ls['duration'].value_counts()
# Out:
# 30785       2
# 30788       2
# 30782       2
# 864368      1
# 186012      1
# 53828       1
# 76972       1
# 323243      1
# 81578       1
# 38057       1
# 76966       1
# 30884       1
# 274506      1
# 71842       1
# 74399       1
# 33438       1
# 741421      1
# 105643      1
# 204741      1
# 406677      1
# 174228      1
# 87187       1
# 82066       1
# 1594512     1
# 79501       1
# 163980      1
# 79526       1
# 59017       1
# 62596       1
# 69247       1
#            ..
# 143691      1
# 177047      1
# 97499       1
# 2148191     1
# 605022      1
# 407894      1
# 4439893     1
# 1084755     1
# 11256146    1
# 31978       1
# 1760080     1
# 52046       1
# 579917      1
# 148812      1
# 99657       1
# 41264       1
# 120648      1
# 846663      1
# 1303379     1
# 208195      1
# 161601      1
# 37694       1
# 2190139     1
# 148792      1
# 164151      1
# 146742      1
# 346932      1
# 36028       1
# 82151       1
# 315392      1
# ...

# %%
ls['activity'].value_counts()
# Out:
# 1    165
# 2     60
# 4     37
# 5      2
# 3      1
# Name: activity, dtype: int64

# %%
labels ='36 months', '60 months ','36 months', '60 months ', '60 months '
colors = ['lightskyblue', 'lightcoral']
plt.pie(ls['activity'].value_counts(),labels=labels,colors=colors,shadow=True,startangle=90)
plt.show()

# %%
7+8
